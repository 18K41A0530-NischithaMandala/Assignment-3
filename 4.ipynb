# %%
#4.Write a numpy program to compute the condition number of a given matrix [[1 2][3 4]] condition number of said matrix :14.9330343737
import numpy as np
import numpy.linalg as nl
array2=np.array([[1,2],[3,4]])
x=nl.cond(array2)
x
# Out:
# 14.933034373659265
